# %% [markdown]
# <a href="https://colab.research.google.com/github/perigor/EngenhariadeDados-Growdev/blob/main/C%C3%B3pia_de_Modelagem_de_um_Sistema_de_E_commerce_GrowDev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Modelagem de um Sistema de E-commerce - GrowDev_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Modelagem de um Sistema de E-commerce - GrowDev_page-0004.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Modelagem de um Sistema de E-commerce - GrowDev_page-0005.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Modelagem de BD - Ecomerce02.png](data:image/png;base64,...)

# %% [markdown]
# ![Sem título.png](data:image/png;base64,...)
